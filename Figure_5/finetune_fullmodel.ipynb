# %% [markdown]
# # Finetune 2kb full Borzoi model into CREsted-style scalar model
#
# For a better tutorial, look at the CREsted documentation's Borzoi finetuning guide.

# %%
import os
import zipfile
import tempfile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import anndata as ad
import tensorflow as tf
import keras
import wandb
import crested
# Out:
# 2025-03-20 14:06:28.735970: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-20 14:06:28.773300: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-20 14:06:30.890073: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# Download the data for the notebooks from the dedicated Zenodo link of the CREsted paper. Then use it below.

# %%
DATA_DIR = "../../../crested_data/Figure_5/"

# %%
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: cas-blaauw. Use `wandb login --relogin` to force relogin
# True

# %%
# Data paths
adata_file = f"{DATA_DIR}data/mouse_biccn_data_full.h5ad" # see data/README.md, data from crested.get_dataset("mouse_cortex_bigwig_cut_sites")
adata_filtered_file = f"{DATA_DIR}data/mouse_biccn_data_specific.h5ad"
folds_file = f"{DATA_DIR}data/consensus_peaks_biccn_borzoifolds.tsv"
# Genome paths
resources_dir = "../../../mouse/biccn/" # CHANGE TO OWN
genome_file = os.path.join(resources_dir, "mm10.fa")
chromsizes_file = os.path.join(resources_dir, "mm10.chrom.sizes")

# %%
genome = crested.Genome(genome_file, chromsizes_file)
crested.register_genome(genome)
# Out:
# 2025-03-20T14:07:50.479641+0100 INFO Genome mm10 registered.

# %%
frozen = False
borsplit = False

# %% [markdown]
# ## First round training

# %% [markdown]
# ### Read in ATAC data

# %%
if os.path.exists(adata_file):
    adata = ad.read_h5ad(adata_file)
else:
    atac_dir, regions_file = crested.get_dataset("mouse_cortex_bigwig_cut_sites")
    adata = crested.import_bigwigs(
        bigwigs_folder=atac_dir,
        regions_file=regions_file,
        target_region_width=1000, 
        target="count",
    )
    crested.pp.train_val_test_split(
        adata, strategy="chr", val_chroms=["chr8", "chr10"], test_chroms=["chr9", "chr18"]
    )
    crested.pp.change_regions_width(
        adata,
        2048,
        chromsizes_file=chromsizes_file,
    )
    crested.pp.normalize_peaks(
        adata, top_k_percent=0.03
    )  # The top_k_percent parameters can be tuned based on potential bias towards cell types. If some weights are overcompensating too much, consider increasing the top_k_percent. Default is 0.01
# Out:
# 2025-03-06T10:33:47.807612+0100 INFO Extracting values from 19 bigWig files...
# AnnData object with n_obs × n_vars = 19 × 546993
#     obs: 'file_path'
#     var: 'chr', 'start', 'end'

# %% [markdown]
# ### Training split

# %% [markdown]
# #### Use standard split or use Borzoi folds

# %%
if not borsplit:
    crested.pp.train_val_test_split(
        adata, strategy="chr", val_chroms=["chr8", "chr10"], test_chroms=["chr9", "chr18"]
    )
    print(adata.var['split'].value_counts(dropna=False))
else:
    val_train_folds = {'fold4': 'val', 'fold3': 'test'}

    if 'fold' in adata.var.columns:
        adata.var = adata.var.drop(['fold'], axis = 1)
    if 'split' in adata.var.columns:
        print("Warning: dropping previous split information and adding Borzoi split info")
        adata.var = adata.var.drop(['split'], axis = 1)
    
    # Read in and resize folds file to match 2048bp regions
    folds = pd.read_csv(folds_file, sep = '\t', names = ['chr', 'start', 'end', 'region', 'fold'], usecols = ['region',  'fold'])
    folds_split = folds['region'].str.extract(r"(?P<chr>chr.+):(?P<start>\d+)-(?P<end>\d+)")
    folds_split['center'] = (folds_split['start'].astype(int) + folds_split['end'].astype(int)) // 2
    folds_split['new_start'] = folds_split['center'] - 2048//2
    folds_split['new_end'] = folds_split['center'] + 2048//2
    folds['region'] =  folds_split['chr']+':'+folds_split['new_start'].astype(str)+'-'+folds_split['new_end'].astype(str)
    folds = folds.set_index('region')
    
    # Drop duplicates (on edge of folds)
    folds = folds[~folds.index.duplicated(False)]
    
    # Drop regions not in any folds
    print(f"Dropping {(~adata.var_names.isin(folds.index)).sum()} regions because they are not in any fold.")
    adata = adata[:, adata.var_names.isin(folds.index)].copy()
    
    # Add fold data to var
    adata.var = adata.var.join(folds)
    
    # Turn fold data into split data
    fold_mapping = {fold: 'train' for fold in folds['fold'].unique()}
    fold_mapping.update(val_train_folds)
    adata.var['split'] = adata.var['fold'].map(fold_mapping)
    
    # Check result
    print(adata.var['split'].value_counts(dropna=False))

# %% [markdown]
# ### Model definition

# %%
# Load in default Borzoi architecture, with shrunk input size
base_model_architecture = crested.tl.zoo.borzoi(seq_len=2048, target_length = 64, num_classes = (7611, 2608))
# Load in original Borzoi weights
model_file, _ = crested.get_model("Borzoi_mouse_rep0")
# Put weights into base architecture
with zipfile.ZipFile(model_file) as model_archive, tempfile.TemporaryDirectory() as tmpdir:
    model_weights_path = model_archive.extract('model.weights.h5', tmpdir)
    base_model_architecture.load_weights(model_weights_path)

# To train Frozen Borzoi
if frozen:
    for layer in base_model_architecture.layers:
        layer.trainable = False

# Replace track head by flatten+dense to predict single vector of scalars per region
## Get last layer before head
current = base_model_architecture.get_layer("final_conv_activation").output
## Flatten and add new layer
current = keras.layers.Flatten()(current)
current = keras.layers.Dense(
    adata.n_obs, activation='softplus', name="dense_out"
)(current)
## Turn into model
model_architecture = keras.Model(inputs = base_model_architecture.inputs, outputs = current, name = 'Borzoi_scalar')
print(model_architecture.summary())
# Out:
# 2025-03-06 13:40:47.383422: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 78783 MB memory:  -> device: 0, name: NVIDIA H100 80GB HBM3, pci bus id: 0000:c6:00.0, compute capability: 9.0
# Model: "Borzoi_scalar"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 2048, 4)   │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv1D)  │ (None, 2048, 512) │     31,232 │ input[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_pool           │ (None, 1024, 512) │          0 │ stem_conv[0][0]   │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_1_batch… │ (None, 1024, 512) │      2,048 │ stem_pool[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_1_activ… │ (None, 1024, 512) │          0 │ tower_conv_1_bat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_1_conv   │ (None, 1024, 608) │  1,557,088 │ tower_conv_1_act… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_1_pool   │ (None, 512, 608)  │          0 │ tower_conv_1_con… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_2_batch… │ (None, 512, 608)  │      2,432 │ tower_conv_1_poo… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_2_activ… │ (None, 512, 608)  │          0 │ tower_conv_2_bat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_2_conv   │ (None, 512, 736)  │  2,238,176 │ tower_conv_2_act… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_2_pool   │ (None, 256, 736)  │          0 │ tower_conv_2_con… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_3_batch… │ (None, 256, 736)  │      2,944 │ tower_conv_2_poo… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_3_activ… │ (None, 256, 736)  │          0 │ tower_conv_3_bat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_3_conv   │ (None, 256, 896)  │  3,298,176 │ tower_conv_3_act… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_3_pool   │ (None, 128, 896)  │          0 │ tower_conv_3_con… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_4_batch… │ (None, 128, 896)  │      3,584 │ tower_conv_3_poo… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_4_activ… │ (None, 128, 896)  │          0 │ tower_conv_4_bat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_4_conv   │ (None, 128, 1056) │  4,731,936 │ tower_conv_4_act… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_4_pool   │ (None, 64, 1056)  │          0 │ tower_conv_4_con… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_5_batch… │ (None, 64, 1056)  │      4,224 │ tower_conv_4_poo… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_5_activ… │ (None, 64, 1056)  │          0 │ tower_conv_5_bat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_5_conv   │ (None, 64, 1280)  │  6,759,680 │ tower_conv_5_act… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_5_pool   │ (None, 32, 1280)  │          0 │ tower_conv_5_con… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_6_batch… │ (None, 32, 1280)  │      5,120 │ tower_conv_5_poo… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_6_activ… │ (None, 32, 1280)  │          0 │ tower_conv_6_bat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_6_conv   │ (None, 32, 1536)  │  9,831,936 │ tower_conv_6_act… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_6_pool   │ (None, 16, 1536)  │          0 │ tower_conv_6_con… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_1_… │ (None, 16, 1536)  │      3,072 │ tower_conv_6_poo… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_1_… │ (None, 16, 1536)  │  6,310,400 │ transformer_mha_… │
# │ (MultiheadAttentio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_1_… │ (None, 16, 1536)  │          0 │ transformer_mha_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 16, 1536)  │          0 │ tower_conv_6_poo… │
# │                     │                   │            │ transformer_mha_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_1_l… │ (None, 16, 1536)  │      3,072 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_1_p… │ (None, 16, 3072)  │  4,721,664 │ transformer_ff_1… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_1_d… │ (None, 16, 3072)  │          0 │ transformer_ff_1… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_1_a… │ (None, 16, 3072)  │          0 │ transformer_ff_1… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_1_p… │ (None, 16, 1536)  │  4,720,128 │ transformer_ff_1… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_1_d… │ (None, 16, 1536)  │          0 │ transformer_ff_1… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 16, 1536)  │          0 │ add[0][0],        │
# │                     │                   │            │ transformer_ff_1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_2_… │ (None, 16, 1536)  │      3,072 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_2_… │ (None, 16, 1536)  │  6,310,400 │ transformer_mha_… │
# │ (MultiheadAttentio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_2_… │ (None, 16, 1536)  │          0 │ transformer_mha_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 16, 1536)  │          0 │ add_1[0][0],      │
# │                     │                   │            │ transformer_mha_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_2_l… │ (None, 16, 1536)  │      3,072 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_2_p… │ (None, 16, 3072)  │  4,721,664 │ transformer_ff_2… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_2_d… │ (None, 16, 3072)  │          0 │ transformer_ff_2… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_2_a… │ (None, 16, 3072)  │          0 │ transformer_ff_2… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_2_p… │ (None, 16, 1536)  │  4,720,128 │ transformer_ff_2… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_2_d… │ (None, 16, 1536)  │          0 │ transformer_ff_2… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 16, 1536)  │          0 │ add_2[0][0],      │
# │                     │                   │            │ transformer_ff_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_3_… │ (None, 16, 1536)  │      3,072 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_3_… │ (None, 16, 1536)  │  6,310,400 │ transformer_mha_… │
# │ (MultiheadAttentio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_3_… │ (None, 16, 1536)  │          0 │ transformer_mha_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 16, 1536)  │          0 │ add_3[0][0],      │
# │                     │                   │            │ transformer_mha_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_3_l… │ (None, 16, 1536)  │      3,072 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_3_p… │ (None, 16, 3072)  │  4,721,664 │ transformer_ff_3… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_3_d… │ (None, 16, 3072)  │          0 │ transformer_ff_3… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_3_a… │ (None, 16, 3072)  │          0 │ transformer_ff_3… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_3_p… │ (None, 16, 1536)  │  4,720,128 │ transformer_ff_3… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_3_d… │ (None, 16, 1536)  │          0 │ transformer_ff_3… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 16, 1536)  │          0 │ add_4[0][0],      │
# │                     │                   │            │ transformer_ff_3… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_4_… │ (None, 16, 1536)  │      3,072 │ add_5[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_4_… │ (None, 16, 1536)  │  6,310,400 │ transformer_mha_… │
# │ (MultiheadAttentio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_4_… │ (None, 16, 1536)  │          0 │ transformer_mha_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 16, 1536)  │          0 │ add_5[0][0],      │
# │                     │                   │            │ transformer_mha_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_4_l… │ (None, 16, 1536)  │      3,072 │ add_6[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_4_p… │ (None, 16, 3072)  │  4,721,664 │ transformer_ff_4… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_4_d… │ (None, 16, 3072)  │          0 │ transformer_ff_4… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_4_a… │ (None, 16, 3072)  │          0 │ transformer_ff_4… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_4_p… │ (None, 16, 1536)  │  4,720,128 │ transformer_ff_4… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_4_d… │ (None, 16, 1536)  │          0 │ transformer_ff_4… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 16, 1536)  │          0 │ add_6[0][0],      │
# │                     │                   │            │ transformer_ff_4… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_5_… │ (None, 16, 1536)  │      3,072 │ add_7[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_5_… │ (None, 16, 1536)  │  6,310,400 │ transformer_mha_… │
# │ (MultiheadAttentio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_5_… │ (None, 16, 1536)  │          0 │ transformer_mha_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 16, 1536)  │          0 │ add_7[0][0],      │
# │                     │                   │            │ transformer_mha_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_5_l… │ (None, 16, 1536)  │      3,072 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_5_p… │ (None, 16, 3072)  │  4,721,664 │ transformer_ff_5… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_5_d… │ (None, 16, 3072)  │          0 │ transformer_ff_5… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_5_a… │ (None, 16, 3072)  │          0 │ transformer_ff_5… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_5_p… │ (None, 16, 1536)  │  4,720,128 │ transformer_ff_5… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_5_d… │ (None, 16, 1536)  │          0 │ transformer_ff_5… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 16, 1536)  │          0 │ add_8[0][0],      │
# │                     │                   │            │ transformer_ff_5… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_6_… │ (None, 16, 1536)  │      3,072 │ add_9[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_6_… │ (None, 16, 1536)  │  6,310,400 │ transformer_mha_… │
# │ (MultiheadAttentio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_6_… │ (None, 16, 1536)  │          0 │ transformer_mha_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 16, 1536)  │          0 │ add_9[0][0],      │
# │                     │                   │            │ transformer_mha_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_6_l… │ (None, 16, 1536)  │      3,072 │ add_10[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_6_p… │ (None, 16, 3072)  │  4,721,664 │ transformer_ff_6… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_6_d… │ (None, 16, 3072)  │          0 │ transformer_ff_6… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_6_a… │ (None, 16, 3072)  │          0 │ transformer_ff_6… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_6_p… │ (None, 16, 1536)  │  4,720,128 │ transformer_ff_6… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_6_d… │ (None, 16, 1536)  │          0 │ transformer_ff_6… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 16, 1536)  │          0 │ add_10[0][0],     │
# │                     │                   │            │ transformer_ff_6… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_7_… │ (None, 16, 1536)  │      3,072 │ add_11[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_7_… │ (None, 16, 1536)  │  6,310,400 │ transformer_mha_… │
# │ (MultiheadAttentio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_7_… │ (None, 16, 1536)  │          0 │ transformer_mha_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 16, 1536)  │          0 │ add_11[0][0],     │
# │                     │                   │            │ transformer_mha_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_7_l… │ (None, 16, 1536)  │      3,072 │ add_12[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_7_p… │ (None, 16, 3072)  │  4,721,664 │ transformer_ff_7… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_7_d… │ (None, 16, 3072)  │          0 │ transformer_ff_7… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_7_a… │ (None, 16, 3072)  │          0 │ transformer_ff_7… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_7_p… │ (None, 16, 1536)  │  4,720,128 │ transformer_ff_7… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_7_d… │ (None, 16, 1536)  │          0 │ transformer_ff_7… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 16, 1536)  │          0 │ add_12[0][0],     │
# │                     │                   │            │ transformer_ff_7… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_8_… │ (None, 16, 1536)  │      3,072 │ add_13[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_8_… │ (None, 16, 1536)  │  6,310,400 │ transformer_mha_… │
# │ (MultiheadAttentio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_8_… │ (None, 16, 1536)  │          0 │ transformer_mha_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 16, 1536)  │          0 │ add_13[0][0],     │
# │                     │                   │            │ transformer_mha_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_8_l… │ (None, 16, 1536)  │      3,072 │ add_14[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_8_p… │ (None, 16, 3072)  │  4,721,664 │ transformer_ff_8… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_8_d… │ (None, 16, 3072)  │          0 │ transformer_ff_8… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_8_a… │ (None, 16, 3072)  │          0 │ transformer_ff_8… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_8_p… │ (None, 16, 1536)  │  4,720,128 │ transformer_ff_8… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_8_d… │ (None, 16, 1536)  │          0 │ transformer_ff_8… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 16, 1536)  │          0 │ add_14[0][0],     │
# │                     │                   │            │ transformer_ff_8… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upsampling_conv_1_… │ (None, 16, 1536)  │      6,144 │ add_15[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upsampling_conv_1_… │ (None, 16, 1536)  │          0 │ upsampling_conv_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ unet_skip_2_batchn… │ (None, 32, 1536)  │      6,144 │ tower_conv_6_con… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upsampling_conv_1_… │ (None, 16, 1536)  │  2,360,832 │ upsampling_conv_… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ unet_skip_2_activa… │ (None, 32, 1536)  │          0 │ unet_skip_2_batc… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling1d       │ (None, 32, 1536)  │          0 │ upsampling_conv_… │
# │ (UpSampling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ unet_skip_2_conv    │ (None, 32, 1536)  │  2,360,832 │ unet_skip_2_acti… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 32, 1536)  │          0 │ up_sampling1d[0]… │
# │                     │                   │            │ unet_skip_2_conv… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upsampling_separab… │ (None, 32, 1536)  │  2,365,440 │ add_16[0][0]      │
# │ (SeparableConv1D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upsampling_conv_2_… │ (None, 32, 1536)  │      6,144 │ upsampling_separ… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upsampling_conv_2_… │ (None, 32, 1536)  │          0 │ upsampling_conv_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ unet_skip_1_batchn… │ (None, 64, 1280)  │      5,120 │ tower_conv_5_con… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upsampling_conv_2_… │ (None, 32, 1536)  │  2,360,832 │ upsampling_conv_… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ unet_skip_1_activa… │ (None, 64, 1280)  │          0 │ unet_skip_1_batc… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling1d_1     │ (None, 64, 1536)  │          0 │ upsampling_conv_… │
# │ (UpSampling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ unet_skip_1_conv    │ (None, 64, 1536)  │  1,967,616 │ unet_skip_1_acti… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 64, 1536)  │          0 │ up_sampling1d_1[… │
# │                     │                   │            │ unet_skip_1_conv… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upsampling_separab… │ (None, 64, 1536)  │  2,365,440 │ add_17[0][0]      │
# │ (SeparableConv1D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_conv_batchno… │ (None, 64, 1536)  │      6,144 │ upsampling_separ… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_conv_activat… │ (None, 64, 1536)  │          0 │ final_conv_batch… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 98304)     │          0 │ final_conv_activ… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_out (Dense)   │ (None, 19)        │  1,867,795 │ flatten[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 170,213,747 (649.31 MB)
#  Trainable params: 1,867,795 (7.13 MB)
#  Non-trainable params: 168,345,952 (642.19 MB)
# None

# %% [markdown]
# ### TaskConfig

# %%
optimizer = keras.optimizers.Adam(learning_rate=5e-5) # 5e-5 for first round finetuning, 1e-5 for second round or frozen
loss = crested.tl.losses.CosineMSELogLoss(max_weight=100, multiplier=1)
metrics = [
    keras.metrics.MeanAbsoluteError(),
    keras.metrics.MeanSquaredError(),
    keras.metrics.CosineSimilarity(axis=1),
    crested.tl.metrics.PearsonCorrelation(),
    crested.tl.metrics.ConcordanceCorrelationCoefficient(),
    crested.tl.metrics.PearsonCorrelationLog(),
    crested.tl.metrics.ZeroPenaltyMetric(),
]

config = crested.tl.TaskConfig(optimizer, loss, metrics)
print(config)

# %% [markdown]
# ### Data module

# %%
datamodule = crested.tl.data.AnnDataModule(
    adata,
    genome=genome,
    batch_size=32,  # lower this if you encounter OOM errors
    max_stochastic_shift=3,  
    always_reverse_complement=True,  
)

# %% [markdown]
# ### Training

# %%
# setup the trainer
trainer = crested.tl.Crested(
    data=datamodule,
    model=model_architecture,
    config=config,
    project_name="biccn_borzoi_atac",
    run_name="borzoi_borsplit_ft_consensus", # Remember to change!
    logger="wandb", 
)

# %%
# train the model
trainer.fit(epochs=10)

# %% [markdown]
# ## Second round training
# ### Read in specific ATAC data

# %%
# This next part is same as running filtering on the previous adata, except for small seed/time of day/idk differences:
# crested.pp.filter_regions_on_specificity(
#     adata, gini_std_threshold=1.0
# )

# %%
# load in pre-saved filtered file
adata = ad.read_h5ad(adata_filtered_file)

# %%
# Re-process data
crested.pp.change_regions_width(
    adata,
    2048,
)

# %%
# Optional: replace fold info by Borzoi fold info if training those models

val_train_folds = {'fold4': 'val', 'fold3': 'test'}

adata.var = adata.var.drop(['split'], axis = 1)

# Read in and resize folds file to match 2048bp regions
folds = pd.read_csv(folds_file, sep = '\t', names = ['chr', 'start', 'end', 'region', 'fold'], usecols = ['region',  'fold'])
folds_split = folds['region'].str.extract(r"(?P<chr>chr.+):(?P<start>\d+)-(?P<end>\d+)")
folds_split['center'] = (folds_split['start'].astype(int) + folds_split['end'].astype(int)) // 2
folds_split['new_start'] = folds_split['center'] - 2048//2
folds_split['new_end'] = folds_split['center'] + 2048//2
folds['region'] =  folds_split['chr']+':'+folds_split['new_start'].astype(str)+'-'+folds_split['new_end'].astype(str)
folds = folds.set_index('region')
print(f"adata length: {adata.n_vars}")
print(f"folds length: {len(folds)}")
print(f"adata in folds length: {adata.var_names.isin(folds.index).sum()}")
print(f"folds in adata length: {folds.index.isin(adata.var_names).sum()}")

# Drop duplicates (on edge of folds)
folds = folds[~folds.index.duplicated(False)]

# Drop regions not in any folds
print(f"Dropping {(~adata.var_names.isin(folds.index)).sum()} regions because they are not in any fold.")
adata = adata[:, adata.var_names.isin(folds.index)].copy()

# Add fold data to var
adata.var = adata.var.join(folds)

# Turn fold data into split data
fold_mapping = {fold: 'train' for fold in folds['fold'].unique()}
fold_mapping.update(val_train_folds)
adata.var['split'] = adata.var['fold'].map(fold_mapping)

# Check result
adata.var['split'].value_counts(dropna=False)
# Out:
# adata length: 91475
# folds length: 543877
# adata in folds length: 91013
# folds in adata length: 91013
# Dropping 462 regions because they are not in any fold.
# split
# train    67153
# val      12974
# test     10886
# Name: count, dtype: int64

# %% [markdown]
# ### Load in model

# %%
model_architecture = keras.models.load_model(
    f"{DATA_DIR}models/borzoi_borsplit_ft_consensus.keras", compile=False 
)
# Out:
# 2025-03-20 14:08:14.674561: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 78790 MB memory:  -> device: 0, name: NVIDIA H100 80GB HBM3, pci bus id: 0000:e4:00.0, compute capability: 9.0

# %% [markdown]
# ### TaskConfig

# %%
optimizer = keras.optimizers.Adam(learning_rate=1e-5) # 5e-5 for first round finetuning, 1e-5 for second round or frozen
loss = crested.tl.losses.CosineMSELogLoss(max_weight=100, multiplier=1)
metrics = [
    keras.metrics.MeanAbsoluteError(),
    keras.metrics.MeanSquaredError(),
    keras.metrics.CosineSimilarity(axis=1),
    crested.tl.metrics.PearsonCorrelation(),
    crested.tl.metrics.ConcordanceCorrelationCoefficient(),
    crested.tl.metrics.PearsonCorrelationLog(),
    crested.tl.metrics.ZeroPenaltyMetric(),
]

config = crested.tl.TaskConfig(optimizer, loss, metrics)
print(config)
# Out:
# TaskConfig(optimizer=<keras.src.optimizers.adam.Adam object at 0x1509c1b3ca50>, loss=<crested.tl.losses._cosinemse_log.CosineMSELogLoss object at 0x1509cb9cee10>, metrics=[<MeanAbsoluteError name=mean_absolute_error>, <MeanSquaredError name=mean_squared_error>, <CosineSimilarity name=cosine_similarity>, <PearsonCorrelation name=pearson_correlation>, <ConcordanceCorrelationCoefficient name=concordance_correlation_coefficient>, <PearsonCorrelationLog name=pearson_correlation_log>, <ZeroPenaltyMetric name=zero_penalty_metric>])

# %% [markdown]
# ### Data module

# %%
datamodule = crested.tl.data.AnnDataModule(
    adata,
    genome=genome,
    batch_size=32,  # lower this if you encounter OOM errors
    max_stochastic_shift=3,  # optional augmentation
    always_reverse_complement=True,  # default True. Will double the effective size of the training dataset.
)

# %% [markdown]
# ### Training

# %%
# setup the trainer
trainer = crested.tl.Crested(
    data=datamodule,
    model=model_architecture,
    config=config,
    project_name="biccn_borzoi_atac",
    run_name="borzoi_borsplit_ft_consensus_ft_specific", # Remember to change!
    logger="wandb", 
)

# %%
# train the model
trainer.fit(epochs=30)
# Out:
# wandb version 0.19.8 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.2
# Run data is saved locally in <code>/lustre1/project/stg_00002/lcb/cblaauw/rna_models/borzoi_atac/wandb/run-20250306_134146-g5ojg33h</code>
# Syncing run <strong><a href='https://wandb.ai/cas-blaauw/biccn_borzoi_atac/runs/g5ojg33h' target="_blank">scalar_cutsites_nkset_fullmodel_frozen_borsplit</a></strong> to <a href='https://wandb.ai/cas-blaauw/biccn_borzoi_atac' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/cas-blaauw/biccn_borzoi_atac' target="_blank">https://wandb.ai/cas-blaauw/biccn_borzoi_atac</a>
#  View run at <a href='https://wandb.ai/cas-blaauw/biccn_borzoi_atac/runs/g5ojg33h' target="_blank">https://wandb.ai/cas-blaauw/biccn_borzoi_atac/runs/g5ojg33h</a>
# Model: "Borzoi_scalar"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 2048, 4)   │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv1D)  │ (None, 2048, 512) │     31,232 │ input[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_pool           │ (None, 1024, 512) │          0 │ stem_conv[0][0]   │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_1_batch… │ (None, 1024, 512) │      2,048 │ stem_pool[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_1_activ… │ (None, 1024, 512) │          0 │ tower_conv_1_bat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_1_conv   │ (None, 1024, 608) │  1,557,088 │ tower_conv_1_act… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_1_pool   │ (None, 512, 608)  │          0 │ tower_conv_1_con… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_2_batch… │ (None, 512, 608)  │      2,432 │ tower_conv_1_poo… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_2_activ… │ (None, 512, 608)  │          0 │ tower_conv_2_bat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_2_conv   │ (None, 512, 736)  │  2,238,176 │ tower_conv_2_act… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_2_pool   │ (None, 256, 736)  │          0 │ tower_conv_2_con… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_3_batch… │ (None, 256, 736)  │      2,944 │ tower_conv_2_poo… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_3_activ… │ (None, 256, 736)  │          0 │ tower_conv_3_bat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_3_conv   │ (None, 256, 896)  │  3,298,176 │ tower_conv_3_act… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_3_pool   │ (None, 128, 896)  │          0 │ tower_conv_3_con… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_4_batch… │ (None, 128, 896)  │      3,584 │ tower_conv_3_poo… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_4_activ… │ (None, 128, 896)  │          0 │ tower_conv_4_bat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_4_conv   │ (None, 128, 1056) │  4,731,936 │ tower_conv_4_act… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_4_pool   │ (None, 64, 1056)  │          0 │ tower_conv_4_con… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_5_batch… │ (None, 64, 1056)  │      4,224 │ tower_conv_4_poo… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_5_activ… │ (None, 64, 1056)  │          0 │ tower_conv_5_bat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_5_conv   │ (None, 64, 1280)  │  6,759,680 │ tower_conv_5_act… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_5_pool   │ (None, 32, 1280)  │          0 │ tower_conv_5_con… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_6_batch… │ (None, 32, 1280)  │      5,120 │ tower_conv_5_poo… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_6_activ… │ (None, 32, 1280)  │          0 │ tower_conv_6_bat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_6_conv   │ (None, 32, 1536)  │  9,831,936 │ tower_conv_6_act… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tower_conv_6_pool   │ (None, 16, 1536)  │          0 │ tower_conv_6_con… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_1_… │ (None, 16, 1536)  │      3,072 │ tower_conv_6_poo… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_1_… │ (None, 16, 1536)  │  6,310,400 │ transformer_mha_… │
# │ (MultiheadAttentio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_1_… │ (None, 16, 1536)  │          0 │ transformer_mha_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 16, 1536)  │          0 │ tower_conv_6_poo… │
# │                     │                   │            │ transformer_mha_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_1_l… │ (None, 16, 1536)  │      3,072 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_1_p… │ (None, 16, 3072)  │  4,721,664 │ transformer_ff_1… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_1_d… │ (None, 16, 3072)  │          0 │ transformer_ff_1… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_1_a… │ (None, 16, 3072)  │          0 │ transformer_ff_1… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_1_p… │ (None, 16, 1536)  │  4,720,128 │ transformer_ff_1… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_1_d… │ (None, 16, 1536)  │          0 │ transformer_ff_1… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 16, 1536)  │          0 │ add[0][0],        │
# │                     │                   │            │ transformer_ff_1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_2_… │ (None, 16, 1536)  │      3,072 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_2_… │ (None, 16, 1536)  │  6,310,400 │ transformer_mha_… │
# │ (MultiheadAttentio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_2_… │ (None, 16, 1536)  │          0 │ transformer_mha_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 16, 1536)  │          0 │ add_1[0][0],      │
# │                     │                   │            │ transformer_mha_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_2_l… │ (None, 16, 1536)  │      3,072 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_2_p… │ (None, 16, 3072)  │  4,721,664 │ transformer_ff_2… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_2_d… │ (None, 16, 3072)  │          0 │ transformer_ff_2… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_2_a… │ (None, 16, 3072)  │          0 │ transformer_ff_2… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_2_p… │ (None, 16, 1536)  │  4,720,128 │ transformer_ff_2… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_2_d… │ (None, 16, 1536)  │          0 │ transformer_ff_2… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 16, 1536)  │          0 │ add_2[0][0],      │
# │                     │                   │            │ transformer_ff_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_3_… │ (None, 16, 1536)  │      3,072 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_3_… │ (None, 16, 1536)  │  6,310,400 │ transformer_mha_… │
# │ (MultiheadAttentio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_3_… │ (None, 16, 1536)  │          0 │ transformer_mha_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 16, 1536)  │          0 │ add_3[0][0],      │
# │                     │                   │            │ transformer_mha_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_3_l… │ (None, 16, 1536)  │      3,072 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_3_p… │ (None, 16, 3072)  │  4,721,664 │ transformer_ff_3… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_3_d… │ (None, 16, 3072)  │          0 │ transformer_ff_3… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_3_a… │ (None, 16, 3072)  │          0 │ transformer_ff_3… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_3_p… │ (None, 16, 1536)  │  4,720,128 │ transformer_ff_3… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_3_d… │ (None, 16, 1536)  │          0 │ transformer_ff_3… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 16, 1536)  │          0 │ add_4[0][0],      │
# │                     │                   │            │ transformer_ff_3… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_4_… │ (None, 16, 1536)  │      3,072 │ add_5[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_4_… │ (None, 16, 1536)  │  6,310,400 │ transformer_mha_… │
# │ (MultiheadAttentio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_4_… │ (None, 16, 1536)  │          0 │ transformer_mha_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 16, 1536)  │          0 │ add_5[0][0],      │
# │                     │                   │            │ transformer_mha_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_4_l… │ (None, 16, 1536)  │      3,072 │ add_6[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_4_p… │ (None, 16, 3072)  │  4,721,664 │ transformer_ff_4… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_4_d… │ (None, 16, 3072)  │          0 │ transformer_ff_4… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_4_a… │ (None, 16, 3072)  │          0 │ transformer_ff_4… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_4_p… │ (None, 16, 1536)  │  4,720,128 │ transformer_ff_4… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_4_d… │ (None, 16, 1536)  │          0 │ transformer_ff_4… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 16, 1536)  │          0 │ add_6[0][0],      │
# │                     │                   │            │ transformer_ff_4… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_5_… │ (None, 16, 1536)  │      3,072 │ add_7[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_5_… │ (None, 16, 1536)  │  6,310,400 │ transformer_mha_… │
# │ (MultiheadAttentio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_5_… │ (None, 16, 1536)  │          0 │ transformer_mha_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 16, 1536)  │          0 │ add_7[0][0],      │
# │                     │                   │            │ transformer_mha_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_5_l… │ (None, 16, 1536)  │      3,072 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_5_p… │ (None, 16, 3072)  │  4,721,664 │ transformer_ff_5… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_5_d… │ (None, 16, 3072)  │          0 │ transformer_ff_5… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_5_a… │ (None, 16, 3072)  │          0 │ transformer_ff_5… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_5_p… │ (None, 16, 1536)  │  4,720,128 │ transformer_ff_5… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_5_d… │ (None, 16, 1536)  │          0 │ transformer_ff_5… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 16, 1536)  │          0 │ add_8[0][0],      │
# │                     │                   │            │ transformer_ff_5… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_6_… │ (None, 16, 1536)  │      3,072 │ add_9[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_6_… │ (None, 16, 1536)  │  6,310,400 │ transformer_mha_… │
# │ (MultiheadAttentio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_6_… │ (None, 16, 1536)  │          0 │ transformer_mha_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 16, 1536)  │          0 │ add_9[0][0],      │
# │                     │                   │            │ transformer_mha_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_6_l… │ (None, 16, 1536)  │      3,072 │ add_10[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_6_p… │ (None, 16, 3072)  │  4,721,664 │ transformer_ff_6… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_6_d… │ (None, 16, 3072)  │          0 │ transformer_ff_6… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_6_a… │ (None, 16, 3072)  │          0 │ transformer_ff_6… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_6_p… │ (None, 16, 1536)  │  4,720,128 │ transformer_ff_6… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_6_d… │ (None, 16, 1536)  │          0 │ transformer_ff_6… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 16, 1536)  │          0 │ add_10[0][0],     │
# │                     │                   │            │ transformer_ff_6… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_7_… │ (None, 16, 1536)  │      3,072 │ add_11[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_7_… │ (None, 16, 1536)  │  6,310,400 │ transformer_mha_… │
# │ (MultiheadAttentio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_7_… │ (None, 16, 1536)  │          0 │ transformer_mha_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 16, 1536)  │          0 │ add_11[0][0],     │
# │                     │                   │            │ transformer_mha_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_7_l… │ (None, 16, 1536)  │      3,072 │ add_12[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_7_p… │ (None, 16, 3072)  │  4,721,664 │ transformer_ff_7… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_7_d… │ (None, 16, 3072)  │          0 │ transformer_ff_7… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_7_a… │ (None, 16, 3072)  │          0 │ transformer_ff_7… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_7_p… │ (None, 16, 1536)  │  4,720,128 │ transformer_ff_7… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_7_d… │ (None, 16, 1536)  │          0 │ transformer_ff_7… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 16, 1536)  │          0 │ add_12[0][0],     │
# │                     │                   │            │ transformer_ff_7… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_8_… │ (None, 16, 1536)  │      3,072 │ add_13[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_8_… │ (None, 16, 1536)  │  6,310,400 │ transformer_mha_… │
# │ (MultiheadAttentio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_mha_8_… │ (None, 16, 1536)  │          0 │ transformer_mha_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 16, 1536)  │          0 │ add_13[0][0],     │
# │                     │                   │            │ transformer_mha_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_8_l… │ (None, 16, 1536)  │      3,072 │ add_14[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_8_p… │ (None, 16, 3072)  │  4,721,664 │ transformer_ff_8… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_8_d… │ (None, 16, 3072)  │          0 │ transformer_ff_8… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_8_a… │ (None, 16, 3072)  │          0 │ transformer_ff_8… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_8_p… │ (None, 16, 1536)  │  4,720,128 │ transformer_ff_8… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_ff_8_d… │ (None, 16, 1536)  │          0 │ transformer_ff_8… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 16, 1536)  │          0 │ add_14[0][0],     │
# │                     │                   │            │ transformer_ff_8… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upsampling_conv_1_… │ (None, 16, 1536)  │      6,144 │ add_15[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upsampling_conv_1_… │ (None, 16, 1536)  │          0 │ upsampling_conv_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ unet_skip_2_batchn… │ (None, 32, 1536)  │      6,144 │ tower_conv_6_con… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upsampling_conv_1_… │ (None, 16, 1536)  │  2,360,832 │ upsampling_conv_… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ unet_skip_2_activa… │ (None, 32, 1536)  │          0 │ unet_skip_2_batc… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling1d       │ (None, 32, 1536)  │          0 │ upsampling_conv_… │
# │ (UpSampling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ unet_skip_2_conv    │ (None, 32, 1536)  │  2,360,832 │ unet_skip_2_acti… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 32, 1536)  │          0 │ up_sampling1d[0]… │
# │                     │                   │            │ unet_skip_2_conv… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upsampling_separab… │ (None, 32, 1536)  │  2,365,440 │ add_16[0][0]      │
# │ (SeparableConv1D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upsampling_conv_2_… │ (None, 32, 1536)  │      6,144 │ upsampling_separ… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upsampling_conv_2_… │ (None, 32, 1536)  │          0 │ upsampling_conv_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ unet_skip_1_batchn… │ (None, 64, 1280)  │      5,120 │ tower_conv_5_con… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upsampling_conv_2_… │ (None, 32, 1536)  │  2,360,832 │ upsampling_conv_… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ unet_skip_1_activa… │ (None, 64, 1280)  │          0 │ unet_skip_1_batc… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling1d_1     │ (None, 64, 1536)  │          0 │ upsampling_conv_… │
# │ (UpSampling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ unet_skip_1_conv    │ (None, 64, 1536)  │  1,967,616 │ unet_skip_1_acti… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 64, 1536)  │          0 │ up_sampling1d_1[… │
# │                     │                   │            │ unet_skip_1_conv… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upsampling_separab… │ (None, 64, 1536)  │  2,365,440 │ add_17[0][0]      │
# │ (SeparableConv1D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_conv_batchno… │ (None, 64, 1536)  │      6,144 │ upsampling_separ… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_conv_activat… │ (None, 64, 1536)  │          0 │ final_conv_batch… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 98304)     │          0 │ final_conv_activ… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_out (Dense)   │ (None, 19)        │  1,867,795 │ flatten[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 170,213,747 (649.31 MB)
#  Trainable params: 1,867,795 (7.13 MB)
#  Non-trainable params: 168,345,952 (642.19 MB)
# None
# 2025-03-06T13:42:21.893388+0100 INFO Loading sequences into memory...
# 100%|██████████| 67153/67153 [00:54<00:00, 1232.42it/s]
# 2025-03-06T13:43:16.751253+0100 INFO Loading sequences into memory...
# 100%|██████████| 12974/12974 [00:04<00:00, 3190.76it/s]
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741265009.359234  378410 service.cc:145] XLA service 0x15093c010a70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1741265009.379141  378410 service.cc:153]   StreamExecutor device (0): NVIDIA H100 80GB HBM3, Compute Capability 9.0
# 2025-03-06 13:43:35.604812: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-03-06 13:43:44.691680: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8902
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741265061.248790  378790 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_65', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1741265075.481889  378410 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# wandb: ERROR Unable to log learning rate.
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 169s 23ms/step - concordance_correlation_coefficient: 0.2283 - cosine_similarity: 0.7186 - loss: -0.2981 - mean_absolute_error: 2.2493 - mean_squared_error: 26.7955 - pearson_correlation: 0.5089 - pearson_correlation_log: 0.5275 - zero_penalty_metric: 339.9114 - val_concordance_correlation_coefficient: 0.3568 - val_cosine_similarity: 0.7695 - val_loss: -0.4136 - val_mean_absolute_error: 2.1054 - val_mean_squared_error: 23.1069 - val_pearson_correlation: 0.6280 - val_pearson_correlation_log: 0.5342 - val_zero_penalty_metric: 311.6286 - learning_rate: 1.0000e-05
# Epoch 2/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 49s 12ms/step - concordance_correlation_coefficient: 0.3683 - cosine_similarity: 0.7732 - loss: -0.4295 - mean_absolute_error: 2.0794 - mean_squared_error: 23.4079 - pearson_correlation: 0.6356 - pearson_correlation_log: 0.5384 - zero_penalty_metric: 321.4921 - val_concordance_correlation_coefficient: 0.3951 - val_cosine_similarity: 0.7780 - val_loss: -0.4317 - val_mean_absolute_error: 2.0731 - val_mean_squared_error: 22.0350 - val_pearson_correlation: 0.6418 - val_pearson_correlation_log: 0.5246 - val_zero_penalty_metric: 313.7423 - learning_rate: 1.0000e-05
# Epoch 3/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 50s 12ms/step - concordance_correlation_coefficient: 0.3972 - cosine_similarity: 0.7826 - loss: -0.4483 - mean_absolute_error: 2.0438 - mean_squared_error: 22.2490 - pearson_correlation: 0.6473 - pearson_correlation_log: 0.5379 - zero_penalty_metric: 319.4920 - val_concordance_correlation_coefficient: 0.4002 - val_cosine_similarity: 0.7809 - val_loss: -0.4363 - val_mean_absolute_error: 2.0670 - val_mean_squared_error: 21.8680 - val_pearson_correlation: 0.6491 - val_pearson_correlation_log: 0.5229 - val_zero_penalty_metric: 315.4659 - learning_rate: 1.0000e-05
# Epoch 4/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 49s 12ms/step - concordance_correlation_coefficient: 0.4122 - cosine_similarity: 0.7876 - loss: -0.4594 - mean_absolute_error: 2.0220 - mean_squared_error: 21.7039 - pearson_correlation: 0.6566 - pearson_correlation_log: 0.5400 - zero_penalty_metric: 319.1897 - val_concordance_correlation_coefficient: 0.4031 - val_cosine_similarity: 0.7848 - val_loss: -0.4407 - val_mean_absolute_error: 2.0549 - val_mean_squared_error: 21.8745 - val_pearson_correlation: 0.6546 - val_pearson_correlation_log: 0.5162 - val_zero_penalty_metric: 313.1721 - learning_rate: 1.0000e-05
# Epoch 5/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 49s 12ms/step - concordance_correlation_coefficient: 0.4190 - cosine_similarity: 0.7919 - loss: -0.4681 - mean_absolute_error: 2.0149 - mean_squared_error: 21.7544 - pearson_correlation: 0.6619 - pearson_correlation_log: 0.5425 - zero_penalty_metric: 317.5420 - val_concordance_correlation_coefficient: 0.4215 - val_cosine_similarity: 0.7850 - val_loss: -0.4476 - val_mean_absolute_error: 2.0450 - val_mean_squared_error: 21.3053 - val_pearson_correlation: 0.6546 - val_pearson_correlation_log: 0.5288 - val_zero_penalty_metric: 313.6234 - learning_rate: 1.0000e-05
# Epoch 6/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 48s 11ms/step - concordance_correlation_coefficient: 0.4258 - cosine_similarity: 0.7952 - loss: -0.4748 - mean_absolute_error: 2.0007 - mean_squared_error: 21.2894 - pearson_correlation: 0.6656 - pearson_correlation_log: 0.5443 - zero_penalty_metric: 317.1440 - val_concordance_correlation_coefficient: 0.4217 - val_cosine_similarity: 0.7858 - val_loss: -0.4473 - val_mean_absolute_error: 2.0452 - val_mean_squared_error: 21.3000 - val_pearson_correlation: 0.6570 - val_pearson_correlation_log: 0.5304 - val_zero_penalty_metric: 313.5511 - learning_rate: 1.0000e-05
# Epoch 7/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 48s 11ms/step - concordance_correlation_coefficient: 0.4291 - cosine_similarity: 0.7972 - loss: -0.4791 - mean_absolute_error: 1.9970 - mean_squared_error: 21.3521 - pearson_correlation: 0.6684 - pearson_correlation_log: 0.5460 - zero_penalty_metric: 317.3247 - val_concordance_correlation_coefficient: 0.4221 - val_cosine_similarity: 0.7855 - val_loss: -0.4465 - val_mean_absolute_error: 2.0500 - val_mean_squared_error: 21.2377 - val_pearson_correlation: 0.6571 - val_pearson_correlation_log: 0.5242 - val_zero_penalty_metric: 314.3736 - learning_rate: 1.0000e-05
# Epoch 8/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 49s 12ms/step - concordance_correlation_coefficient: 0.4336 - cosine_similarity: 0.7989 - loss: -0.4821 - mean_absolute_error: 1.9960 - mean_squared_error: 21.2959 - pearson_correlation: 0.6722 - pearson_correlation_log: 0.5463 - zero_penalty_metric: 316.5306 - val_concordance_correlation_coefficient: 0.4260 - val_cosine_similarity: 0.7873 - val_loss: -0.4507 - val_mean_absolute_error: 2.0403 - val_mean_squared_error: 21.1500 - val_pearson_correlation: 0.6589 - val_pearson_correlation_log: 0.5260 - val_zero_penalty_metric: 313.2183 - learning_rate: 1.0000e-05
# Epoch 9/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 48s 11ms/step - concordance_correlation_coefficient: 0.4380 - cosine_similarity: 0.8013 - loss: -0.4869 - mean_absolute_error: 1.9898 - mean_squared_error: 21.1367 - pearson_correlation: 0.6747 - pearson_correlation_log: 0.5493 - zero_penalty_metric: 316.8274 - val_concordance_correlation_coefficient: 0.4214 - val_cosine_similarity: 0.7885 - val_loss: -0.4502 - val_mean_absolute_error: 2.0366 - val_mean_squared_error: 21.3391 - val_pearson_correlation: 0.6618 - val_pearson_correlation_log: 0.5330 - val_zero_penalty_metric: 308.9740 - learning_rate: 1.0000e-05
# Epoch 10/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 49s 12ms/step - concordance_correlation_coefficient: 0.4393 - cosine_similarity: 0.8026 - loss: -0.4900 - mean_absolute_error: 1.9794 - mean_squared_error: 20.9747 - pearson_correlation: 0.6744 - pearson_correlation_log: 0.5509 - zero_penalty_metric: 316.1615 - val_concordance_correlation_coefficient: 0.4336 - val_cosine_similarity: 0.7891 - val_loss: -0.4552 - val_mean_absolute_error: 2.0312 - val_mean_squared_error: 20.9716 - val_pearson_correlation: 0.6611 - val_pearson_correlation_log: 0.5346 - val_zero_penalty_metric: 309.4891 - learning_rate: 1.0000e-05
# Epoch 11/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 48s 11ms/step - concordance_correlation_coefficient: 0.4432 - cosine_similarity: 0.8042 - loss: -0.4927 - mean_absolute_error: 1.9800 - mean_squared_error: 20.9568 - pearson_correlation: 0.6776 - pearson_correlation_log: 0.5523 - zero_penalty_metric: 314.7591 - val_concordance_correlation_coefficient: 0.4267 - val_cosine_similarity: 0.7889 - val_loss: -0.4505 - val_mean_absolute_error: 2.0358 - val_mean_squared_error: 21.1661 - val_pearson_correlation: 0.6639 - val_pearson_correlation_log: 0.5129 - val_zero_penalty_metric: 317.8258 - learning_rate: 1.0000e-05
# Epoch 12/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 47s 11ms/step - concordance_correlation_coefficient: 0.4456 - cosine_similarity: 0.8053 - loss: -0.4959 - mean_absolute_error: 1.9679 - mean_squared_error: 20.7243 - pearson_correlation: 0.6793 - pearson_correlation_log: 0.5521 - zero_penalty_metric: 316.3232 - val_concordance_correlation_coefficient: 0.4352 - val_cosine_similarity: 0.7900 - val_loss: -0.4548 - val_mean_absolute_error: 2.0294 - val_mean_squared_error: 20.9324 - val_pearson_correlation: 0.6640 - val_pearson_correlation_log: 0.5358 - val_zero_penalty_metric: 311.2431 - learning_rate: 1.0000e-05
# Epoch 13/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 48s 11ms/step - concordance_correlation_coefficient: 0.4479 - cosine_similarity: 0.8075 - loss: -0.4993 - mean_absolute_error: 1.9746 - mean_squared_error: 20.9450 - pearson_correlation: 0.6819 - pearson_correlation_log: 0.5549 - zero_penalty_metric: 314.2186 - val_concordance_correlation_coefficient: 0.4285 - val_cosine_similarity: 0.7899 - val_loss: -0.4526 - val_mean_absolute_error: 2.0347 - val_mean_squared_error: 21.1080 - val_pearson_correlation: 0.6645 - val_pearson_correlation_log: 0.5288 - val_zero_penalty_metric: 313.6673 - learning_rate: 1.0000e-05
# Epoch 14/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 48s 11ms/step - concordance_correlation_coefficient: 0.4500 - cosine_similarity: 0.8088 - loss: -0.5019 - mean_absolute_error: 1.9663 - mean_squared_error: 20.7043 - pearson_correlation: 0.6827 - pearson_correlation_log: 0.5548 - zero_penalty_metric: 314.6893 - val_concordance_correlation_coefficient: 0.4349 - val_cosine_similarity: 0.7896 - val_loss: -0.4544 - val_mean_absolute_error: 2.0321 - val_mean_squared_error: 20.8994 - val_pearson_correlation: 0.6641 - val_pearson_correlation_log: 0.5199 - val_zero_penalty_metric: 315.9835 - learning_rate: 1.0000e-05
# Epoch 15/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 50s 12ms/step - concordance_correlation_coefficient: 0.4527 - cosine_similarity: 0.8096 - loss: -0.5037 - mean_absolute_error: 1.9631 - mean_squared_error: 20.7182 - pearson_correlation: 0.6838 - pearson_correlation_log: 0.5554 - zero_penalty_metric: 314.6709 - val_concordance_correlation_coefficient: 0.4383 - val_cosine_similarity: 0.7898 - val_loss: -0.4555 - val_mean_absolute_error: 2.0305 - val_mean_squared_error: 20.8139 - val_pearson_correlation: 0.6641 - val_pearson_correlation_log: 0.5300 - val_zero_penalty_metric: 313.6848 - learning_rate: 1.0000e-05
# Epoch 16/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 48s 11ms/step - concordance_correlation_coefficient: 0.4521 - cosine_similarity: 0.8102 - loss: -0.5043 - mean_absolute_error: 1.9681 - mean_squared_error: 20.8513 - pearson_correlation: 0.6849 - pearson_correlation_log: 0.5559 - zero_penalty_metric: 313.2251 - val_concordance_correlation_coefficient: 0.4369 - val_cosine_similarity: 0.7897 - val_loss: -0.4539 - val_mean_absolute_error: 2.0263 - val_mean_squared_error: 20.8893 - val_pearson_correlation: 0.6650 - val_pearson_correlation_log: 0.5214 - val_zero_penalty_metric: 312.8804 - learning_rate: 1.0000e-05
# Epoch 17/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 49s 12ms/step - concordance_correlation_coefficient: 0.4552 - cosine_similarity: 0.8115 - loss: -0.5076 - mean_absolute_error: 1.9550 - mean_squared_error: 20.4953 - pearson_correlation: 0.6853 - pearson_correlation_log: 0.5567 - zero_penalty_metric: 314.7454 - val_concordance_correlation_coefficient: 0.4420 - val_cosine_similarity: 0.7903 - val_loss: -0.4575 - val_mean_absolute_error: 2.0220 - val_mean_squared_error: 20.7475 - val_pearson_correlation: 0.6658 - val_pearson_correlation_log: 0.5378 - val_zero_penalty_metric: 307.5326 - learning_rate: 1.0000e-05
# Epoch 18/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 48s 11ms/step - concordance_correlation_coefficient: 0.4566 - cosine_similarity: 0.8124 - loss: -0.5084 - mean_absolute_error: 1.9586 - mean_squared_error: 20.4998 - pearson_correlation: 0.6876 - pearson_correlation_log: 0.5564 - zero_penalty_metric: 312.9073 - val_concordance_correlation_coefficient: 0.4382 - val_cosine_similarity: 0.7913 - val_loss: -0.4559 - val_mean_absolute_error: 2.0225 - val_mean_squared_error: 20.8929 - val_pearson_correlation: 0.6670 - val_pearson_correlation_log: 0.5243 - val_zero_penalty_metric: 310.6212 - learning_rate: 1.0000e-05
# Epoch 19/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 48s 11ms/step - concordance_correlation_coefficient: 0.4597 - cosine_similarity: 0.8138 - loss: -0.5113 - mean_absolute_error: 1.9560 - mean_squared_error: 20.5020 - pearson_correlation: 0.6894 - pearson_correlation_log: 0.5563 - zero_penalty_metric: 312.3539 - val_concordance_correlation_coefficient: 0.4400 - val_cosine_similarity: 0.7907 - val_loss: -0.4553 - val_mean_absolute_error: 2.0242 - val_mean_squared_error: 20.8043 - val_pearson_correlation: 0.6672 - val_pearson_correlation_log: 0.5306 - val_zero_penalty_metric: 310.9778 - learning_rate: 1.0000e-05
# Epoch 20/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 48s 11ms/step - concordance_correlation_coefficient: 0.4603 - cosine_similarity: 0.8141 - loss: -0.5119 - mean_absolute_error: 1.9541 - mean_squared_error: 20.4511 - pearson_correlation: 0.6892 - pearson_correlation_log: 0.5580 - zero_penalty_metric: 313.5327 - val_concordance_correlation_coefficient: 0.4414 - val_cosine_similarity: 0.7906 - val_loss: -0.4558 - val_mean_absolute_error: 2.0238 - val_mean_squared_error: 20.7672 - val_pearson_correlation: 0.6661 - val_pearson_correlation_log: 0.5262 - val_zero_penalty_metric: 310.1100 - learning_rate: 1.0000e-05
# Epoch 21/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 48s 11ms/step - concordance_correlation_coefficient: 0.4610 - cosine_similarity: 0.8153 - loss: -0.5145 - mean_absolute_error: 1.9494 - mean_squared_error: 20.4507 - pearson_correlation: 0.6891 - pearson_correlation_log: 0.5580 - zero_penalty_metric: 313.4338 - val_concordance_correlation_coefficient: 0.4387 - val_cosine_similarity: 0.7913 - val_loss: -0.4542 - val_mean_absolute_error: 2.0232 - val_mean_squared_error: 20.8823 - val_pearson_correlation: 0.6680 - val_pearson_correlation_log: 0.5270 - val_zero_penalty_metric: 310.1181 - learning_rate: 1.0000e-05
# Epoch 22/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 48s 11ms/step - concordance_correlation_coefficient: 0.4611 - cosine_similarity: 0.8159 - loss: -0.5152 - mean_absolute_error: 1.9496 - mean_squared_error: 20.4902 - pearson_correlation: 0.6902 - pearson_correlation_log: 0.5577 - zero_penalty_metric: 311.8637 - val_concordance_correlation_coefficient: 0.4434 - val_cosine_similarity: 0.7913 - val_loss: -0.4568 - val_mean_absolute_error: 2.0235 - val_mean_squared_error: 20.7017 - val_pearson_correlation: 0.6690 - val_pearson_correlation_log: 0.5271 - val_zero_penalty_metric: 312.1459 - learning_rate: 1.0000e-05
# Epoch 23/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 49s 12ms/step - concordance_correlation_coefficient: 0.4619 - cosine_similarity: 0.8184 - loss: -0.5210 - mean_absolute_error: 1.9426 - mean_squared_error: 20.4440 - pearson_correlation: 0.6933 - pearson_correlation_log: 0.5619 - zero_penalty_metric: 312.9987 - val_concordance_correlation_coefficient: 0.4413 - val_cosine_similarity: 0.7933 - val_loss: -0.4608 - val_mean_absolute_error: 2.0173 - val_mean_squared_error: 20.7617 - val_pearson_correlation: 0.6711 - val_pearson_correlation_log: 0.5330 - val_zero_penalty_metric: 311.7995 - learning_rate: 2.5000e-06
# Epoch 24/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 49s 12ms/step - concordance_correlation_coefficient: 0.4625 - cosine_similarity: 0.8191 - loss: -0.5231 - mean_absolute_error: 1.9379 - mean_squared_error: 20.3916 - pearson_correlation: 0.6943 - pearson_correlation_log: 0.5623 - zero_penalty_metric: 313.8782 - val_concordance_correlation_coefficient: 0.4411 - val_cosine_similarity: 0.7931 - val_loss: -0.4608 - val_mean_absolute_error: 2.0177 - val_mean_squared_error: 20.7741 - val_pearson_correlation: 0.6702 - val_pearson_correlation_log: 0.5372 - val_zero_penalty_metric: 309.0915 - learning_rate: 2.5000e-06
# Epoch 25/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 48s 11ms/step - concordance_correlation_coefficient: 0.4629 - cosine_similarity: 0.8200 - loss: -0.5240 - mean_absolute_error: 1.9414 - mean_squared_error: 20.4115 - pearson_correlation: 0.6956 - pearson_correlation_log: 0.5628 - zero_penalty_metric: 313.8134 - val_concordance_correlation_coefficient: 0.4420 - val_cosine_similarity: 0.7927 - val_loss: -0.4605 - val_mean_absolute_error: 2.0188 - val_mean_squared_error: 20.7220 - val_pearson_correlation: 0.6702 - val_pearson_correlation_log: 0.5326 - val_zero_penalty_metric: 312.8326 - learning_rate: 2.5000e-06
# Epoch 26/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 49s 12ms/step - concordance_correlation_coefficient: 0.4646 - cosine_similarity: 0.8204 - loss: -0.5255 - mean_absolute_error: 1.9361 - mean_squared_error: 20.3130 - pearson_correlation: 0.6976 - pearson_correlation_log: 0.5634 - zero_penalty_metric: 314.2226 - val_concordance_correlation_coefficient: 0.4423 - val_cosine_similarity: 0.7929 - val_loss: -0.4620 - val_mean_absolute_error: 2.0177 - val_mean_squared_error: 20.7039 - val_pearson_correlation: 0.6700 - val_pearson_correlation_log: 0.5383 - val_zero_penalty_metric: 310.6648 - learning_rate: 2.5000e-06
# Epoch 27/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 49s 12ms/step - concordance_correlation_coefficient: 0.4608 - cosine_similarity: 0.8195 - loss: -0.5231 - mean_absolute_error: 1.9450 - mean_squared_error: 20.5795 - pearson_correlation: 0.6946 - pearson_correlation_log: 0.5640 - zero_penalty_metric: 313.7756 - val_concordance_correlation_coefficient: 0.4425 - val_cosine_similarity: 0.7935 - val_loss: -0.4623 - val_mean_absolute_error: 2.0152 - val_mean_squared_error: 20.7276 - val_pearson_correlation: 0.6706 - val_pearson_correlation_log: 0.5348 - val_zero_penalty_metric: 311.5120 - learning_rate: 2.5000e-06
# Epoch 28/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 48s 11ms/step - concordance_correlation_coefficient: 0.4628 - cosine_similarity: 0.8202 - loss: -0.5258 - mean_absolute_error: 1.9348 - mean_squared_error: 20.2479 - pearson_correlation: 0.6949 - pearson_correlation_log: 0.5640 - zero_penalty_metric: 314.3006 - val_concordance_correlation_coefficient: 0.4400 - val_cosine_similarity: 0.7933 - val_loss: -0.4609 - val_mean_absolute_error: 2.0165 - val_mean_squared_error: 20.8049 - val_pearson_correlation: 0.6708 - val_pearson_correlation_log: 0.5339 - val_zero_penalty_metric: 310.7969 - learning_rate: 2.5000e-06
# Epoch 29/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 48s 11ms/step - concordance_correlation_coefficient: 0.4635 - cosine_similarity: 0.8203 - loss: -0.5257 - mean_absolute_error: 1.9329 - mean_squared_error: 20.2585 - pearson_correlation: 0.6963 - pearson_correlation_log: 0.5641 - zero_penalty_metric: 314.5667 - val_concordance_correlation_coefficient: 0.4403 - val_cosine_similarity: 0.7934 - val_loss: -0.4608 - val_mean_absolute_error: 2.0175 - val_mean_squared_error: 20.7892 - val_pearson_correlation: 0.6714 - val_pearson_correlation_log: 0.5323 - val_zero_penalty_metric: 312.8747 - learning_rate: 2.5000e-06
# Epoch 30/30
# 4198/4198 ━━━━━━━━━━━━━━━━━━━━ 48s 11ms/step - concordance_correlation_coefficient: 0.4628 - cosine_similarity: 0.8205 - loss: -0.5253 - mean_absolute_error: 1.9370 - mean_squared_error: 20.3444 - pearson_correlation: 0.6962 - pearson_correlation_log: 0.5644 - zero_penalty_metric: 314.9680 - val_concordance_correlation_coefficient: 0.4441 - val_cosine_similarity: 0.7930 - val_loss: -0.4621 - val_mean_absolute_error: 2.0150 - val_mean_squared_error: 20.6836 - val_pearson_correlation: 0.6699 - val_pearson_correlation_log: 0.5400 - val_zero_penalty_metric: 309.2991 - learning_rate: 2.5000e-06
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch/batch_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>batch/concordance_correlation_coefficient</td><td>▁▃▅▆▇▇▇▇▇▇▇▇▇▇▇▇▇███████████████████████</td></tr><tr><td>batch/cosine_similarity</td><td>▁▃▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇████████████████</td></tr><tr><td>batch/loss</td><td>█▆▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>batch/mean_absolute_error</td><td>█▆▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▂▂▂▁▂▂▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>batch/mean_squared_error</td><td>█▆▄▃▂▃▂▂▂▂▂▂▂▂▂▂▂▁▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>batch/pearson_correlation</td><td>▁▄▆▆▇▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█▇█████████████████</td></tr><tr><td>batch/pearson_correlation_log</td><td>▂▃▃▃▄▃▄▄▅▁▅▅▅▆▆▆▆▆▆▆▆▇▆▇▆▇▇▇▇█▇█████████</td></tr><tr><td>batch/zero_penalty_metric</td><td>█▆▄▃▃▃▃▃▃▁▃▃▃▂▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>epoch/concordance_correlation_coefficient</td><td>▁▁▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇█████████████████████</td></tr><tr><td>epoch/cosine_similarity</td><td>▁▁▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇████████████</td></tr><tr><td>epoch/epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>epoch/learning_rate</td><td>██████████████████████████████▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>██▅▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/mean_absolute_error</td><td>██▅▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/mean_squared_error</td><td>██▄▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/pearson_correlation</td><td>▁▁▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇████████████████</td></tr><tr><td>epoch/pearson_correlation_log</td><td>▁▁▁▁▂▂▂▃▃▃▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▆▇▇▇█████████</td></tr><tr><td>epoch/val_concordance_correlation_coefficient</td><td>▁▁▄▄▅▅▆▆▆▆▇▆▇▇▇▇▇▇▇█▇▇██████████████████</td></tr><tr><td>epoch/val_cosine_similarity</td><td>▁▁▃▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇██████████</td></tr><tr><td>epoch/val_loss</td><td>██▅▅▄▄▃▃▃▃▃▃▂▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>██▅▅▄▄▃▃▄▄▃▃▂▂▃▂▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_mean_squared_error</td><td>██▅▄▄▄▃▃▃▃▂▃▂▂▂▂▂▂▂▁▂▂▁▂▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_pearson_correlation</td><td>▁▁▃▄▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇████████████</td></tr><tr><td>epoch/val_pearson_correlation_log</td><td>▇▇▄▄▂▂▅▆▄▄▄▆▇▇▁▇▅▅▃▅▃▃▇▄▆▆▄▅▅▅▆▇▆▆█▇▆▆▆█</td></tr><tr><td>epoch/val_zero_penalty_metric</td><td>▄▄▅▆▅▅▅▅▆▆▅▂▂▂█▄▅▅▇▅▅▅▁▃▃▃▃▃▄▄▄▂▅▅▃▄▃▃▅▂</td></tr><tr><td>epoch/zero_penalty_metric</td><td>██▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch/batch_step</td><td>125990</td></tr><tr><td>batch/concordance_correlation_coefficient</td><td>0.46259</td></tr><tr><td>batch/cosine_similarity</td><td>0.82001</td></tr><tr><td>batch/loss</td><td>-0.52494</td></tr><tr><td>batch/mean_absolute_error</td><td>1.93689</td></tr><tr><td>batch/mean_squared_error</td><td>20.3576</td></tr><tr><td>batch/pearson_correlation</td><td>0.69555</td></tr><tr><td>batch/pearson_correlation_log</td><td>0.56386</td></tr><tr><td>batch/zero_penalty_metric</td><td>314.23633</td></tr><tr><td>epoch/concordance_correlation_coefficient</td><td>0.46262</td></tr><tr><td>epoch/cosine_similarity</td><td>0.82002</td></tr><tr><td>epoch/epoch</td><td>29</td></tr><tr><td>epoch/learning_rate</td><td>0.0</td></tr><tr><td>epoch/loss</td><td>-0.52492</td></tr><tr><td>epoch/mean_absolute_error</td><td>1.93721</td></tr><tr><td>epoch/mean_squared_error</td><td>20.36131</td></tr><tr><td>epoch/pearson_correlation</td><td>0.69562</td></tr><tr><td>epoch/pearson_correlation_log</td><td>0.56387</td></tr><tr><td>epoch/val_concordance_correlation_coefficient</td><td>0.44407</td></tr><tr><td>epoch/val_cosine_similarity</td><td>0.793</td></tr><tr><td>epoch/val_loss</td><td>-0.46213</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>2.01501</td></tr><tr><td>epoch/val_mean_squared_error</td><t ...
#  View run <strong style="color:#cdcd00">scalar_cutsites_nkset_fullmodel_frozen_borsplit</strong> at: <a href='https://wandb.ai/cas-blaauw/biccn_borzoi_atac/runs/g5ojg33h' target="_blank">https://wandb.ai/cas-blaauw/biccn_borzoi_atac/runs/g5ojg33h</a><br/> View project at: <a href='https://wandb.ai/cas-blaauw/biccn_borzoi_atac' target="_blank">https://wandb.ai/cas-blaauw/biccn_borzoi_atac</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20250306_134146-g5ojg33h/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
